# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **John Sandor**   <br>
# Data Scientist or Statistical Consultant

# %% [markdown]
# *I am interested in data science because of the impact that it can have given recent advancements in computing power*

# %% [markdown]
# Code in cell 5 adds one plus one. It should output 2.

# %%
1+1
# Out:
# 2

# %% [markdown]
# - Bulleted List
# - Item 1
# - Item 2
#
# Horizontal Line Below
# ********************************
#
# ~stike this~
